# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('../../')
from modules.plots import performance_fairness
plt.rcParams['figure.max_open_warning'] = 0

# %%
configs = [
    "P2_S20",
    "P20_S20",
    "P200_S20",
    "P2_S50",
    "P20_S50",
    "P200_S50"
]
for config in configs:
    results_df = pd.read_csv(f'results/results-{config}.csv')
    results_df = results_df[results_df['recall@5FPR'] > 0]
    results_df = results_df.sort_values(by='dataset')
    performance_fairness(results_df, ["recall@5FPR", "fpr_ratio_age", "dataset"], title=config, x_name="Recall", y_name="Predictive Equality (Age)", hue_name="Dataset", text_scale=1)
    performance_fairness(results_df, ["recall@5FPR", "fpr_ratio_income", "dataset"], title=config, x_name="Recall", y_name="Predictive Equality (Income)", hue_name="Dataset", text_scale=1)
    performance_fairness(results_df, ["recall@5FPR", "fpr_ratio_employment", "dataset"], title=config, x_name="Recall", y_name="Predictive Equality (Employment Status)", hue_name="Dataset", text_scale=1)
