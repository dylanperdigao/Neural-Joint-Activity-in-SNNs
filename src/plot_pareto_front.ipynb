# %%
import optuna
import sys
sys.path.append('../../')
from modules.plots import pareto_front

# %%
configs = [
    'S20_P2',
    'S20_P20',
    'S20_P200',
    'S50_P2',
    'S50_P20',
    'S50_P200', 
]
for config in configs:
    study = optuna.load_study(study_name=config, storage='sqlite:///../ciarp2024.db')
    pareto_front(study, title=config, loc='lower right', text_scale=1)
